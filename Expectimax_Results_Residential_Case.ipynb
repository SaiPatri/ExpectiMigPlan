# %% [markdown]
# # <center> Optical Access Network Migration Planning Tool: A "not-so" AI approach </center>

# %% [markdown]
# ## <center> Results for Business Case: Pure Residential Deployment </center>

# %% [markdown]
# ### <center> Author: Sai Kireet Patri&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Date: 01.06.2018</center>

# %% [markdown]
# ### 1.1 Introduction and Brief Methodology Overview

# %% [markdown]
# <p>
# Telecommunications network provider migration is an important step and a much needed to be answered research question in both industry and academia. With the advent of new technologies and services for a host of applications, spread across multiple use-cases, user demands have increased multi-fold in a span of a few years. the onus is on network and physical infrastructure providers to upgrade their infrastructure to migrate to newer technologies. This migration is a multi-dimensional, multi-period planning problem and its solution involves forecasting, dimensioning of network infrastructure and processes, as well as evaluation of their economic costs. For optical network planners, the final technology which will provide 100 Mbps to customer is not as important as the technologies which need to be deployed and the time spent in each of these technologies, while trying to reach the final stage.
# </p>
# <p>
# Hence, the research question we seek to answer is how can a physical infrastructure provider achieve <b>migration of all the different types of subscribers</b> (Residential, Business and ITS) to the highest data-rate, while trying to <b>maintain profitability</b>, given different <b>customer penetrations</b> and taking into account <b>customer churn</b>
# </p>
# <p>
# To find out the best migration times and various technologies involved and trying to maximize the Net Present Value of our project in a particular scenario, we use the expectimax search approach, which is one of the earliest Artificial Intelligence decision rules algorithm and is used extensively in decision theory, game theory, statistics and deep learning. It assumes that in every move, the user (in our case, the physical infrastructure provider) will always choose to maximize their benefits and the opponent (in our case, yearly customer churn) will try to find the weighted average between the good (no churn) and bad(churn) situation, with the weights being the probability that a churn occurs.
# </p>
# <p>
# With this expectimax search we find the expected Net Present Value in each of the four different cases for three different penetration curves (a total of 12 runs). We first choose a deployment area and calculate the number of remote nodes and lengths of ducts and fibers required for each of the 13 different technologies (varying in technology, fiber reach and datarates provided). Then we manually generate an excel file which contains the CAPEX, OPEX, Revenues and yearly cashflows (with and without customer churn), for all these technologies. This excel file is then fed as input to the expectimax search algorithm which tries to find the best possible Net Present Value, given a 10% chance of a 10% customer churn every year. The project's internal rate of return for generating the cash flows is also set to 10%. The expectimax search builds a depth first search tree and keeps adding the present values each year till it finds the maximum NPV. The corresponding path is also stored and both are displayed in the form of a graph.
# </p>

# %% [markdown]
# ### 1.2 Deployment Scenario

# %% [markdown]
# <p>
# For our network deployment scenario, we chose one district in the city of Munich, Germany. First a 7 square km area of Munich Altstadt (city center) is extracted from OpenStreetMaps(TM) and then after a lot of post-processing, the city is cleared in such a way that only the buildings, motorable roads and intersections remain. This work is done in ArcMap 10.3.1. Once we have the buildings and the roads, we can now assume that the central office exists at the central railway station and from there, we can calculate the total lengths of feeder fiber ducts, distribution fiber ducts and last mile fiber ducts. This shortest path routing for the fibers is done by the Network Planning Tool developed as part of the work of one of the doctoral candidates in the Chair of Communication Networks at the Technical University of Munich.
# </p>
# <p>
# Some of the salient features of this area are:
#
#  <li> Area: 7 sq. km.</li>
#  <li> Residential Buildings: 4877</li>
#  <li> Average number of homes per building: 6</li>
#  <li> Total homes: 29262</li>
#  <li> Deployment type: Urban</li>
#
# </p>
# <p>
# For this map, we generate 14 different technologies which vary in fiber reach, technology and data rate provided. These are as follows:
#
# <li> Pure Copper ADSL: 20 Mbps</li>
# <li> Fiber to the cabinet (FTTCab) GPON: 25 Mbps</li>
# <li> Fiber to the Building (FTTB) XGPON: 50 Mbps</li>
# <li> FTTB UDWDM : 50 Mbps (Single Stage greenfield deployment)</li>
# <li> Fiber to the Home (FTTH) UDWDM : 100 Mbps</li>
# <li> FTTH XGPON: 100 Mbps</li>
# <li> FTTCab GPON: 100 Mbps</li>
# <li> FTTB XGPON: 100 Mbps</li>
# <li> FTTB UDWDM: 100 Mbps</li>
# <li> FTTCab Hybridpon: 30 Mbps</li>
# <li> FTTB Hybridpon: 60 Mbps</li>
# <li> FTTH Hybridpon: 100 Mbps</li>
# <li> FTTCab Hybridpon: 100 Mbps</li>
# <li> FTTB Hybridpon: 100 Mbps</li>
#
# </p>

# %%
from IPython.display import Image
Image(filename = r"\\nas.ads.mwn.de\ga47kiw\Windows\Desktop\Master Thesis\arcgis screenshots\munich_nw_dimensioning.png",width=800,height=800)

# %% [markdown]
# #### <center>Munich Altstadt Shortest Path Routing Fiber Layout Output</center>

# %% [markdown]
# ### 1.3 Technoeconomics Summary

# %% [markdown]
# #### 1.3.1 CAPEX

# %%
from IPython.display import Image
Image(filename=r"\\nas.ads.mwn.de\ga47kiw\Windows\Desktop\Master Thesis\arcgis screenshots\capex_residential.png",width=800,height=800)

# %% [markdown]
# #### 1.3.2 OPEX

# %%
from IPython.display import Image
Image(filename=r"\\nas.ads.mwn.de\ga47kiw\Windows\Desktop\Master Thesis\arcgis screenshots\opex_residential.png",width=800,height=800)

# %% [markdown]
# #### 1.3.3 Revenue

# %%
from IPython.display import Image
Image(filename=r"\\nas.ads.mwn.de\ga47kiw\Windows\Desktop\Master Thesis\arcgis screenshots\revenue_residential.png",width=800,height=800)

# %% [markdown]
# ### 1.4 Expectimax Search Results

# %% [markdown]
# NOTE TO SELF: RUN THIS ONLY IF THE RESIDENTIAL JSON FILE HAS BEEN POPULATED

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 18 , 14
# %run -i C:\\Users\\ga47kiw\\PycharmProjects\\tumlknexpectimax\\tumlknexpectimax\\output_parser\\create_output_graphs.py residential

# %% [markdown]
# ### 1.4.1 Discussion of results

# %% [markdown]
# <p style="text-align:justify">Here we look into 4 distinct scenarios which could play out with our business case. The cases are explained briefly below:</p>
# <p style="text-align:justify">
# <li -->
# <i>100 Mbps provided by all technologies AND migrations are not forced</i> - This means that all kinds of FTTx technologies have a possibility to upgrade their subscribers to 100 Mbps, without the addition of civil costs in trying to push the optical cable closer to the subscriber. The migrations to 100 Mbps are not time or policy bound (for e.g. EU Broadband policy is forcing operators to provide 100 Mbps to all residential users by 2025.)</li>
# </p>
# <p style="text-align:justify">
# <li -->
# <i>100 Mbps provided by only FTTH technologies AND migrations are not forced</i> - In literature, speeds of 100 Mbps or higher per residential user are often only provided by fiber to the home technology. Here we add the rule that only fiber to the home technologies can provide the customers with 100 Mbps. The migrations to 100 Mbps are not time or policy bound.
# </li>
# </p>
# <p style="text-align:justify">
# <li -->
# <i>100 Mbps provided by all technologies AND migrations are forced at year 2025</i>- This means that all kinds of FTTx technologies have a possibility to upgrade their subscribers to 100 Mbps, without the addition of civil costs in trying to push the optical cable closer to the subscriber. The migrations to 100 Mbps are time or policy bound and we set the year 2025 where all the connected subscribers must be upgraded to 100 Mbps.
# </li>
# </p>
# <p style="text-align:justify">
# <li -->
# <i>100 Mbps provided by only FTTH technologies AND migrations are forced at year 2025</i>- TIn literature, speeds of 100 Mbps or higher per residential user are often only provided by fiber to the home technology. Here we add the rule that only fiber to the home technologies can provide the customers with 100 Mbps. The migrations to 100 Mbps are time or policy bound and we set the year 2025 where all the connected subscribers must be upgraded to 100 Mbps.
# </li>
# </p>
#
# <p style="text-align:justify">As we can see, the NPVs are the worst in case only FTTH is providing 100 Mbps and network operators are asked to migrate all customers to 100 Mbps at the end of year 7 in a migration window of 15 years. This supports our hypothesis that when only residential customers are present, it does not make sense in providing FTTH technologies to them, since the costs are high and the ARPU of residential subscribers is quite low.</p>
# <p style="text-align:justify">The best NPVs are obtained when we let the Expectimax search run without any constraints. Although this takes time, we see that all the three penetration curves converge to 100 Mbps by 2027. The choice of technology being a Fiber to the building deployment of a single stage UDWDM. (Ref: Section 3.5 Fig 8 of Midterm Report). This is chosen because the CAPEX (mainly civil costs) of deploying this technology is far lower compared to other technologies.</p>
